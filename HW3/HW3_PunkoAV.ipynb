# %%
import pandas as pd
import numpy as np
from scipy.stats import fisher_exact
from scipy import stats
from statsmodels.stats.multitest import multipletests

# %%
expr1 = pd.read_csv("expr1.tsv", sep="\t")
anno1 = pd.read_csv("anno1.tsv", sep="\t")
genes1 = pd.read_csv("genes1.tsv", sep="\t")
expr2 = pd.read_csv("expr2.tsv", sep="\t")
anno2 = pd.read_csv("anno2.tsv", sep="\t")
genes2 = pd.read_csv("genes2.tsv", sep="\t")
expr3 = pd.read_csv("expr3.tsv", sep="\t")
anno3 = pd.read_csv("anno3.tsv", sep="\t")
genes3 = pd.read_csv("genes3.tsv", sep="\t")
expr4 = pd.read_csv("expr4.tsv", sep="\t")
anno4 = pd.read_csv("anno4.tsv", sep="\t")
genes4 = pd.read_csv("genes4.tsv", sep="\t")
expr5 = pd.read_csv("expr5.tsv", sep="\t")
anno5 = pd.read_csv("anno5.tsv", sep="\t")
genes5 = pd.read_csv("genes5.tsv", sep="\t")
expr6 = pd.read_csv("expr6.tsv", sep="\t")
anno6 = pd.read_csv("anno6.tsv", sep="\t")
genes6 = pd.read_csv("genes6.tsv", sep="\t")
expr7 = pd.read_csv("expr7.tsv", sep="\t")
anno7 = pd.read_csv("anno7.tsv", sep="\t")
genes7 = pd.read_csv("genes7.tsv", sep="\t")
expr8 = pd.read_csv("expr8.tsv", sep="\t")
anno8 = pd.read_csv("anno8.tsv", sep="\t")
genes8 = pd.read_csv("genes8.tsv", sep="\t")
expr9 = pd.read_csv("expr9.tsv", sep="\t")
anno9 = pd.read_csv("anno9.tsv", sep="\t")
genes9 = pd.read_csv("genes9.tsv", sep="\t")
expr10 = pd.read_csv("expr10.tsv", sep="\t")
anno10 = pd.read_csv("anno10.tsv", sep="\t")
genes10 = pd.read_csv("genes10.tsv", sep="\t")
expr11 = pd.read_csv("expr11.tsv", sep="\t")
anno11 = pd.read_csv("anno11.tsv", sep="\t")
genes11 = pd.read_csv("genes11.tsv", sep="\t")
expr12 = pd.read_csv("expr12.tsv", sep="\t")
anno12 = pd.read_csv("anno12.tsv", sep="\t")
genes12 = pd.read_csv("genes12.tsv", sep="\t")
expr13 = pd.read_csv("expr13.tsv", sep="\t")
anno13 = pd.read_csv("anno13.tsv", sep="\t")
genes13 = pd.read_csv("genes13.tsv", sep="\t")

# %%
norm1 = expr1.iloc[:, 0:10]
cancer1 = expr1.iloc[:, 10:]

norm2 = expr2.iloc[:, 0:32]
cancer2 = expr2.iloc[:, 32:]

norm3 = expr3.iloc[:, 0:12]
cancer3 = expr3.iloc[:, 12:]

norm4 = expr4.iloc[:, 0:12]
cancer4 = expr4.iloc[:, 12:]

norm5 = expr5.iloc[:, 0:5]
cancer5 = expr5.iloc[:, 5:]

norm6 = expr6.iloc[:, 0:35]
cancer6 = expr6.iloc[:, 35:]

norm7 = expr7.iloc[:, 0:15]
cancer7 = expr7.iloc[:, 15:]

norm8 = expr8.iloc[:, 0:5]
cancer8 = expr8.iloc[:, 5:]

norm9 = expr9.iloc[:, 0:8]
cancer9 = expr9.iloc[:, 8:]

norm10 = expr10.iloc[:, 0:9]
cancer10 = expr10.iloc[:, 9:]

norm11 = expr11.iloc[:, 0:7]
cancer11 = expr11.iloc[:, 7:]

norm12 = expr12.iloc[:, 0:44]
cancer12 = expr12.iloc[:, 44:]

norm13 = expr13.iloc[:, 0:62]
cancer13 = expr13.iloc[:, 62:]

# %%
p1 = []
for i in range(expr1.shape[0]):
    p1.append(stats.mannwhitneyu(norm1.iloc[i, :],
                                    cancer1.iloc[i, :]).pvalue)

pv1 = multipletests(p1, method="fdr_bh")[1]

print(f'1: Экспрессия {np.sum(pv1 < 0.05)} генов статистически достоверно различается между раком и нормой')

p2 = []
for i in range(expr2.shape[0]):
    p2.append(stats.mannwhitneyu(norm2.iloc[i, :],
                                    cancer2.iloc[i, :]).pvalue)

pv2 = multipletests(p2, method="fdr_bh")[1]

print(f'2: Экспрессия {np.sum(pv2 < 0.05)} генов статистически достоверно различается между раком и нормой')

p3 = []
for i in range(expr3.shape[0]):
    p3.append(stats.mannwhitneyu(norm3.iloc[i, :],
                                    cancer3.iloc[i, :]).pvalue)

pv3 = multipletests(p3, method="fdr_bh")[1]

print(f'3: Экспрессия {np.sum(pv3 < 0.05)} генов статистически достоверно различается между раком и нормой')

p4 = []
for i in range(expr4.shape[0]):
    p4.append(stats.mannwhitneyu(norm4.iloc[i, :],
                                    cancer4.iloc[i, :]).pvalue)

pv4 = multipletests(p4, method="fdr_bh")[1]

print(f'4: Экспрессия {np.sum(pv4 < 0.05)} генов статистически достоверно различается между раком и нормой')

p5 = []
for i in range(expr5.shape[0]):
    p5.append(stats.mannwhitneyu(norm5.iloc[i, :],
                                    cancer5.iloc[i, :]).pvalue)
p5 = np.array(p5)
#pv5 = multipletests(p5, method="fdr_bh")[1]

print(f'5: Экспрессия {np.sum(p5 < 0.05)} генов статистически достоверно различается между раком и нормой')

p6 = []
for i in range(expr6.shape[0]):
    p6.append(stats.mannwhitneyu(norm6.iloc[i, :],
                                    cancer6.iloc[i, :]).pvalue)

pv6 = multipletests(p6, method="fdr_bh")[1]

print(f'6: Экспрессия {np.sum(pv6 < 0.05)} генов статистически достоверно различается между раком и нормой')

p7 = []
for i in range(expr7.shape[0]):
    p7.append(stats.mannwhitneyu(norm7.iloc[i, :],
                                    cancer7.iloc[i, :]).pvalue)

pv7 = multipletests(p7, method="fdr_bh")[1]

print(f'7: Экспрессия {np.sum(pv7 < 0.05)} генов статистически достоверно различается между раком и нормой')

p8 = []
for i in range(expr8.shape[0]):
    p8.append(stats.mannwhitneyu(norm8.iloc[i, :],
                                    cancer8.iloc[i, :]).pvalue)
p8 = np.array(p8)
#pv8 = multipletests(p8, method="fdr_bh")[1]

print(f'8: Экспрессия {np.sum(p8 < 0.05)} генов статистически достоверно различается между раком и нормой')

p9 = []
for i in range(expr9.shape[0]):
    p9.append(stats.mannwhitneyu(norm9.iloc[i, :],
                                    cancer9.iloc[i, :]).pvalue)
p9 = np.array(p9)
#pv9 = multipletests(p9, method="fdr_bh")[1]

print(f'9: Экспрессия {np.sum(p9 < 0.05)} генов статистически достоверно различается между раком и нормой')

p10 = []
for i in range(expr10.shape[0]):
    p10.append(stats.mannwhitneyu(norm10.iloc[i, :],
                                    cancer10.iloc[i, :]).pvalue)

pv10 = multipletests(p10, method="fdr_bh")[1]

print(f'10: Экспрессия {np.sum(pv10 < 0.05)} генов статистически достоверно различается между раком и нормой')

p11 = []
for i in range(expr11.shape[0]):
    p11.append(stats.mannwhitneyu(norm11.iloc[i, :],
                                    cancer11.iloc[i, :]).pvalue)
p11 = np.array(p11)
#pv11 = multipletests(p11, method="fdr_bh")[1]

print(f'11: Экспрессия {np.sum(p11 < 0.05)} генов статистически достоверно различается между раком и нормой')

p12 = []
for i in range(expr12.shape[0]):
    p12.append(stats.mannwhitneyu(norm12.iloc[i, :],
                                    cancer12.iloc[i, :]).pvalue)

pv12 = multipletests(p12, method="fdr_bh")[1]

print(f'12: Экспрессия {np.sum(pv12 < 0.05)} генов статистически достоверно различается между раком и нормой')

p13 = []
for i in range(expr13.shape[0]):
    p13.append(stats.mannwhitneyu(norm13.iloc[i, :],
                                    cancer13.iloc[i, :]).pvalue)

pv13 = multipletests(p13, method="fdr_bh")[1]

print(f'13: Экспрессия {np.sum(pv13 < 0.05)} генов статистически достоверно различается между раком и нормой')
# Out:
# 1: Экспрессия 2583 генов статистически достоверно различается между раком и нормой
# 2: Экспрессия 10642 генов статистически достоверно различается между раком и нормой
# 3: Экспрессия 10069 генов статистически достоверно различается между раком и нормой
# 4: Экспрессия 7276 генов статистически достоверно различается между раком и нормой
# 5: Экспрессия 2125 генов статистически достоверно различается между раком и нормой
# 6: Экспрессия 13841 генов статистически достоверно различается между раком и нормой
# 7: Экспрессия 2344 генов статистически достоверно различается между раком и нормой
# 8: Экспрессия 1820 генов статистически достоверно различается между раком и нормой
# 9: Экспрессия 863 генов статистически достоверно различается между раком и нормой
# 10: Экспрессия 2734 генов статистически достоверно различается между раком и нормой
# 11: Экспрессия 2792 генов статистически достоверно различается между раком и нормой
# ...

# %%
genes_under_study1 = genes1["rownames(eset)"][pv1 < 0.05].apply(str)
background_genes1 = genes1["rownames(eset)"][pv1 >= 0.05].apply(str)

genes_under_study2 = genes2["rownames(eset)"][pv2 < 0.05].apply(str)
background_genes2 = genes2["rownames(eset)"][pv2 >= 0.05].apply(str)

genes_under_study3 = genes3["rownames(eset)"][pv3 < 0.05].apply(str)
background_genes3 = genes3["rownames(eset)"][pv3 >= 0.05].apply(str)

genes_under_study4 = genes4["rownames(eset)"][pv4 < 0.05].apply(str)
background_genes4 = genes4["rownames(eset)"][pv4 >= 0.05].apply(str)

genes_under_study5 = genes5["rownames(eset)"][p5 < 0.05].apply(str)
background_genes5 = genes5["rownames(eset)"][p5 >= 0.05].apply(str)

genes_under_study6 = genes6["rownames(eset)"][pv6 < 0.05].apply(str)
background_genes6 = genes6["rownames(eset)"][pv6 >= 0.05].apply(str)

genes_under_study7 = genes7["rownames(eset)"][pv7 < 0.05].apply(str)
background_genes7 = genes7["rownames(eset)"][pv7 >= 0.05].apply(str)

genes_under_study8 = genes8["rownames(eset)"][p8 < 0.05].apply(str)
background_genes8 = genes8["rownames(eset)"][p8 >= 0.05].apply(str)

genes_under_study9 = genes9["rownames(eset)"][p9 < 0.05].apply(str)
background_genes9 = genes9["rownames(eset)"][p9 >= 0.05].apply(str)

genes_under_study10 = genes10["rownames(eset)"][pv10 < 0.05].apply(str)
background_genes10 = genes10["rownames(eset)"][pv10 >= 0.05].apply(str)

genes_under_study11 = genes11["rownames(eset)"][p11 < 0.05].apply(str)
background_genes11 = genes11["rownames(eset)"][p11 >= 0.05].apply(str)

genes_under_study12 = genes12["rownames(eset)"][pv12 < 0.05].apply(str)
background_genes12 = genes12["rownames(eset)"][pv12 >= 0.05].apply(str)

genes_under_study13 = genes13["rownames(eset)"][pv13 < 0.05].apply(str)
background_genes13 = genes13["rownames(eset)"][pv13 >= 0.05].apply(str)

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes1:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study1:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_ARACHIDONIC_ACID_METABOLISM',
#        'KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS',
#        'KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC',
#        'KEGG_CITRATE_CYCLE_TCA_CYCLE', 'KEGG_FATTY_ACID_METABOLISM',
#        'KEGG_OXIDATIVE_PHOSPHORYLATION',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_LYSINE_DEGRADATION', 'KEGG_TYROSINE_METABOLISM',
#        'KEGG_TRYPTOPHAN_METABOLISM', 'KEGG_BETA_ALANINE_METABOLISM',
#        'KEGG_GLUTATHIONE_METABOLISM', 'KEGG_PROPANOATE_METABOLISM',
#        'KEGG_BUTANOATE_METABOLISM',
#        'KEGG_PORPHYRIN_AND_CHLOROPHYLL_METABOLISM',
#        'KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS',
#        'KEGG_LIMONENE_AND_PINENE_DEGRADATION',
#        'KEGG_METABOLISM_OF_XENOBIOTICS_BY_CYTOCHROME_P450',
#        'KEGG_DRUG_METABOLISM_CYTOCHROME_P450',
#        'KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS',
#        'KEGG_PPAR_SIGNALING_PATHWAY', 'KEGG_MAPK_SIGNALING_PATHWAY',
# ...

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes2:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study2:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_N_GLYCAN_BIOSYNTHESIS', 'KEGG_GLYCEROLIPID_METABOLISM',
#        'KEGG_AMINOACYL_TRNA_BIOSYNTHESIS',
#        'KEGG_NON_HOMOLOGOUS_END_JOINING', 'KEGG_LYSOSOME',
#        'KEGG_CIRCADIAN_RHYTHM_MAMMAL', 'KEGG_PENTOSE_PHOSPHATE_PATHWAY',
#        'KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM',
#        'KEGG_FATTY_ACID_METABOLISM', 'KEGG_PURINE_METABOLISM',
#        'KEGG_PYRIMIDINE_METABOLISM',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_ARGININE_AND_PROLINE_METABOLISM', 'KEGG_SULFUR_METABOLISM',
#        'KEGG_RIBOSOME', 'KEGG_RNA_DEGRADATION', 'KEGG_RNA_POLYMERASE',
#        'KEGG_DNA_REPLICATION', 'KEGG_SPLICEOSOME', 'KEGG_PROTEASOME',
#        'KEGG_BASE_EXCISION_REPAIR', 'KEGG_NUCLEOTIDE_EXCISION_REPAIR',
#        'KEGG_MISMATCH_REPAIR', 'KEGG_HOMOLOGOUS_RECOMBINATION',
#        'KEGG_MAPK_SIGNALING_PATHWAY', 'KEGG_CHEMOKINE_SIGNALING_PATHWAY',
#        'KEGG_CELL_CYCLE', 'KEGG_OOCYTE_MEIOSIS',
#        'KEGG_P53_SIGNALING_PATHWAY',
# ...

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes3:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study3:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_N_GLYCAN_BIOSYNTHESIS', 'KEGG_GLYCEROLIPID_METABOLISM',
#        'KEGG_GLYCEROPHOSPHOLIPID_METABOLISM',
#        'KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_LACTO_AND_NEOLACTO_SERIES',
#        'KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS',
#        'KEGG_OXIDATIVE_PHOSPHORYLATION', 'KEGG_PURINE_METABOLISM',
#        'KEGG_PYRIMIDINE_METABOLISM',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_INOSITOL_PHOSPHATE_METABOLISM', 'KEGG_PROPANOATE_METABOLISM',
#        'KEGG_RIBOSOME', 'KEGG_RNA_POLYMERASE', 'KEGG_DNA_REPLICATION',
#        'KEGG_SPLICEOSOME', 'KEGG_PROTEASOME',
#        'KEGG_MAPK_SIGNALING_PATHWAY', 'KEGG_ERBB_SIGNALING_PATHWAY',
#        'KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION',
#        'KEGG_CHEMOKINE_SIGNALING_PATHWAY',
#        'KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM', 'KEGG_CELL_CYCLE',
#        'KEGG_OOCYTE_MEIOSIS', 'KEGG_P53_SIGNALING_PATHWAY',
#        'KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS', 'KEGG_PEROXISOME',
# ...

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes4:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study4:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_LYSOSOME', 'KEGG_PROXIMAL_TUBULE_BICARBONATE_RECLAMATION',
#        'KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION',
#        'KEGG_PRIMARY_IMMUNODEFICIENCY', 'KEGG_GLYCOLYSIS_GLUCONEOGENESIS',
#        'KEGG_CITRATE_CYCLE_TCA_CYCLE',
#        'KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM',
#        'KEGG_FATTY_ACID_METABOLISM', 'KEGG_OXIDATIVE_PHOSPHORYLATION',
#        'KEGG_PURINE_METABOLISM', 'KEGG_PYRIMIDINE_METABOLISM',
#        'KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM',
#        'KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM',
#        'KEGG_CYSTEINE_AND_METHIONINE_METABOLISM',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_LYSINE_DEGRADATION', 'KEGG_ARGININE_AND_PROLINE_METABOLISM',
#        'KEGG_BETA_ALANINE_METABOLISM', 'KEGG_GLUTATHIONE_METABOLISM',
#        'KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM',
#        'KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_CHONDROITIN_SULFATE',
# ...

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes5:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study5:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_CARDIAC_MUSCLE_CONTRACTION',
#        'KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION',
#        'KEGG_GLYCOLYSIS_GLUCONEOGENESIS',
#        'KEGG_OXIDATIVE_PHOSPHORYLATION',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION',
#        'KEGG_TYPE_I_DIABETES_MELLITUS', 'KEGG_ALZHEIMERS_DISEASE',
#        'KEGG_PARKINSONS_DISEASE', 'KEGG_HUNTINGTONS_DISEASE',
#        'KEGG_LEISHMANIA_INFECTION', 'KEGG_AUTOIMMUNE_THYROID_DISEASE',
#        'KEGG_ALLOGRAFT_REJECTION', 'KEGG_GRAFT_VERSUS_HOST_DISEASE',
#        'KEGG_VIRAL_MYOCARDITIS'], dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes6:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study6:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC',
#        'KEGG_DILATED_CARDIOMYOPATHY', 'KEGG_CALCIUM_SIGNALING_PATHWAY',
#        'KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION', 'KEGG_FOCAL_ADHESION',
#        'KEGG_LEUKOCYTE_TRANSENDOTHELIAL_MIGRATION',
#        'KEGG_REGULATION_OF_ACTIN_CYTOSKELETON', 'KEGG_PATHWAYS_IN_CANCER'],
#       dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes7:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study7:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_O_GLYCAN_BIOSYNTHESIS',
#        'KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION',
#        'KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC',
#        'KEGG_GLYCOLYSIS_GLUCONEOGENESIS', 'KEGG_PURINE_METABOLISM',
#        'KEGG_PROPANOATE_METABOLISM', 'KEGG_ERBB_SIGNALING_PATHWAY',
#        'KEGG_CELL_CYCLE', 'KEGG_AXON_GUIDANCE', 'KEGG_FOCAL_ADHESION',
#        'KEGG_TIGHT_JUNCTION', 'KEGG_REGULATION_OF_ACTIN_CYTOSKELETON',
#        'KEGG_PATHWAYS_IN_CANCER', 'KEGG_SMALL_CELL_LUNG_CANCER'],
#       dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes8:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study8:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array([], dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes9:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study9:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array([], dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes10:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study10:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_GLYCEROPHOSPHOLIPID_METABOLISM',
#        'KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS',
#        'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION',
#        'KEGG_PYRUVATE_METABOLISM', 'KEGG_PROPANOATE_METABOLISM',
#        'KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION',
#        'KEGG_AXON_GUIDANCE', 'KEGG_CELL_ADHESION_MOLECULES_CAMS',
#        'KEGG_INTESTINAL_IMMUNE_NETWORK_FOR_IGA_PRODUCTION',
#        'KEGG_LEISHMANIA_INFECTION', 'KEGG_ASTHMA',
#        'KEGG_VIRAL_MYOCARDITIS'], dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes11:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study11:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_GLYCEROLIPID_METABOLISM',
#        'KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION',
#        'KEGG_P53_SIGNALING_PATHWAY', 'KEGG_FOCAL_ADHESION',
#        'KEGG_ECM_RECEPTOR_INTERACTION',
#        'KEGG_COMPLEMENT_AND_COAGULATION_CASCADES',
#        'KEGG_PATHWAYS_IN_CANCER', 'KEGG_SMALL_CELL_LUNG_CANCER'],
#       dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes12:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study12:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array(['KEGG_N_GLYCAN_BIOSYNTHESIS', 'KEGG_AMINOACYL_TRNA_BIOSYNTHESIS',
#        'KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS', 'KEGG_PURINE_METABOLISM',
#        'KEGG_PYRIMIDINE_METABOLISM', 'KEGG_GLUTATHIONE_METABOLISM',
#        'KEGG_RNA_DEGRADATION', 'KEGG_RNA_POLYMERASE', 'KEGG_SPLICEOSOME',
#        'KEGG_PROTEASOME', 'KEGG_CELL_CYCLE', 'KEGG_OOCYTE_MEIOSIS',
#        'KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS', 'KEGG_ENDOCYTOSIS',
#        'KEGG_AXON_GUIDANCE', 'KEGG_VEGF_SIGNALING_PATHWAY',
#        'KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS',
#        'KEGG_PROGESTERONE_MEDIATED_OOCYTE_MATURATION',
#        'KEGG_PATHWAYS_IN_CANCER'], dtype='<U63')

# %%
kegg_pw = {}
for line in open("c2.cp.kegg.v7.5.symbols.gmt.txt"):
    parts = line.strip().split("\t")
    name, desc, genes_lst = parts[0], parts[1], parts[2:]
    kegg_pw[name] = set(genes_lst)

pw_pv = []
pw = []
for pathw, pw_genes in kegg_pw.items():
    background_genes_in = 0
    background_genes_out = 0
    genes_under_study_in = 0
    genes_under_study_out = 0
    for gene in background_genes13:
        if gene in pw_genes:
            background_genes_in += 1
        else:
            background_genes_out += 1
    for gene in genes_under_study13:
        if gene in pw_genes:
            genes_under_study_in += 1
        else:
            genes_under_study_out += 1
    table = np.array([[genes_under_study_in, background_genes_in], [genes_under_study_out, background_genes_out]])
    pw_pv.append(fisher_exact(table, "greater")[1])
    pw.append(pathw)

np.array(pw)[multipletests(pw_pv, method="fdr_bh")[1] < 0.05]
# Out:
# array([], dtype='<U63')

# %%
genes_under_study1 = genes1["rownames(eset)"][expr1.iloc[:,-1]>5].apply(str)
myfile1 = genes_under_study1.tolist()
with open('cancer1.txt', 'w') as f:
     print(myfile1, file=f)

genes_under_study2 = genes2["rownames(eset)"][expr2.iloc[:,-1]>5].apply(str)
myfile2 = genes_under_study2.tolist()
with open('cancer2.txt', 'w') as f:
     print(myfile2, file=f)

genes_under_study3 = genes3["rownames(eset)"][expr3.iloc[:,-1]>5].apply(str)
myfile3 = genes_under_study3.tolist()
with open('cancer3.txt', 'w') as f:
     print(myfile3, file=f)

genes_under_study4 = genes4["rownames(eset)"][expr4.iloc[:,-1]>5].apply(str)
myfile4 = genes_under_study4.tolist()
with open('cancer4.txt', 'w') as f:
     print(myfile4, file=f)

genes_under_study5 = genes5["rownames(eset)"][expr5.iloc[:,-1]>5].apply(str)
myfile5 = genes_under_study5.tolist()
with open('cancer5.txt', 'w') as f:
     print(myfile5, file=f)

genes_under_study6 = genes6["rownames(eset)"][expr6.iloc[:,-1]>5].apply(str)
myfile6 = genes_under_study6.tolist()
with open('cancer6.txt', 'w') as f:
     print(myfile6, file=f)

genes_under_study7 = genes7["rownames(eset)"][expr7.iloc[:,-1]>5].apply(str)
myfile7 = genes_under_study7.tolist()
with open('cancer7.txt', 'w') as f:
     print(myfile7, file=f)

genes_under_study8 = genes8["rownames(eset)"][expr8.iloc[:,-1]>5].apply(str)
myfile8 = genes_under_study8.tolist()
with open('cancer8.txt', 'w') as f:
     print(myfile8, file=f)

genes_under_study9 = genes9["rownames(eset)"][expr9.iloc[:,-1]>5].apply(str)
myfile9 = genes_under_study9.tolist()
with open('cancer9.txt', 'w') as f:
     print(myfile9, file=f)

genes_under_study10 = genes10["rownames(eset)"][expr10.iloc[:,-1]>5].apply(str)
myfile10 = genes_under_study10.tolist()
with open('cancer10.txt', 'w') as f:
     print(myfile10, file=f)

genes_under_study11 = genes11["rownames(eset)"][expr11.iloc[:,-1]>5].apply(str)
myfile11 = genes_under_study11.tolist()
with open('cancer11.txt', 'w') as f:
     print(myfile11, file=f)

genes_under_study12 = genes12["rownames(eset)"][expr12.iloc[:,-1]>5].apply(str)
myfile12 = genes_under_study12.tolist()
with open('cancer12.txt', 'w') as f:
     print(myfile12, file=f)

genes_under_study13 = genes13["rownames(eset)"][expr13.iloc[:,-1]>5].apply(str)
myfile13 = genes_under_study13.tolist()
with open('cancer13.txt', 'w') as f:
     print(myfile13, file=f)

# %%
genes_under_study1 = genes1["rownames(eset)"][expr1.iloc[:,0]>5].apply(str)
myfile1 = genes_under_study1.tolist()
with open('norm1_1.txt', 'w') as f:
     print(myfile1, file=f)

genes_under_study2 = genes2["rownames(eset)"][expr2.iloc[:,0]>5].apply(str)
myfile2 = genes_under_study2.tolist()
with open('norm2_1.txt', 'w') as f:
     print(myfile2, file=f)

genes_under_study3 = genes3["rownames(eset)"][expr3.iloc[:,0]>5].apply(str)
myfile3 = genes_under_study3.tolist()
with open('norm3_1.txt', 'w') as f:
     print(myfile3, file=f)

genes_under_study4 = genes4["rownames(eset)"][expr4.iloc[:,0]>5].apply(str)
myfile4 = genes_under_study4.tolist()
with open('norm4_1.txt', 'w') as f:
     print(myfile4, file=f)

genes_under_study5 = genes5["rownames(eset)"][expr5.iloc[:,0]>5].apply(str)
myfile5 = genes_under_study5.tolist()
with open('norm5_1.txt', 'w') as f:
     print(myfile5, file=f)

genes_under_study6 = genes6["rownames(eset)"][expr6.iloc[:,0]>5].apply(str)
myfile6 = genes_under_study6.tolist()
with open('norm6_1.txt', 'w') as f:
     print(myfile6, file=f)

genes_under_study7 = genes7["rownames(eset)"][expr7.iloc[:,0]>5].apply(str)
myfile7 = genes_under_study7.tolist()
with open('norm7_1.txt', 'w') as f:
     print(myfile7, file=f)

genes_under_study8 = genes8["rownames(eset)"][expr8.iloc[:,0]>5].apply(str)
myfile8 = genes_under_study8.tolist()
with open('norm8_1.txt', 'w') as f:
     print(myfile8, file=f)

genes_under_study9 = genes9["rownames(eset)"][expr9.iloc[:,0]>5].apply(str)
myfile9 = genes_under_study9.tolist()
with open('norm9_1.txt', 'w') as f:
     print(myfile9, file=f)

genes_under_study10 = genes10["rownames(eset)"][expr10.iloc[:,0]>5].apply(str)
myfile10 = genes_under_study10.tolist()
with open('norm10_1.txt', 'w') as f:
     print(myfile10, file=f)

genes_under_study11 = genes11["rownames(eset)"][expr11.iloc[:,0]>5].apply(str)
myfile11 = genes_under_study11.tolist()
with open('norm11_1.txt', 'w') as f:
     print(myfile11, file=f)

genes_under_study12 = genes12["rownames(eset)"][expr12.iloc[:,0]>5].apply(str)
myfile12 = genes_under_study12.tolist()
with open('norm12_1.txt', 'w') as f:
     print(myfile12, file=f)

genes_under_study13 = genes13["rownames(eset)"][expr13.iloc[:,0]>5].apply(str)
myfile13 = genes_under_study13.tolist()
with open('norm13_1.txt', 'w') as f:
     print(myfile13, file=f)

# %%
norm1 = norm1>5
cancer1 = cancer1>5

norm2 = norm2>5
cancer2 = cancer2>5

norm3 = norm3>5
cancer3 = cancer3>5

norm4 = norm4>5
cancer4 = cancer4>5

norm5 = norm5>5
cancer5 = cancer5>5

norm6 = norm6>5
cancer6 = cancer6>5

norm7 = norm7>5
cancer7 = cancer7>5

norm8 = norm8>5
cancer8 = cancer8>5

norm9 = norm9>5
cancer9 = cancer9>5

norm10 = norm10>5
cancer10 = cancer10>5

norm11 = norm11>5
cancer11 = cancer11>5

norm12 = norm12>5
cancer12 = cancer12>5

norm13 = norm13>5
cancer13 = cancer13>5

# %%
norm1['new_col'] = norm1.apply(lambda row: True if True in row.values else False, axis=1)
cancer1['new_col'] = cancer1.apply(lambda row: True if True in row.values else False, axis=1)

norm2['new_col'] = norm2.apply(lambda row: True if True in row.values else False, axis=1)
cancer2['new_col'] = cancer2.apply(lambda row: True if True in row.values else False, axis=1)

norm3['new_col'] = norm3.apply(lambda row: True if True in row.values else False, axis=1)
cancer3['new_col'] = cancer3.apply(lambda row: True if True in row.values else False, axis=1)

norm4['new_col'] = norm4.apply(lambda row: True if True in row.values else False, axis=1)
cancer4['new_col'] = cancer4.apply(lambda row: True if True in row.values else False, axis=1)

norm5['new_col'] = norm5.apply(lambda row: True if True in row.values else False, axis=1)
cancer5['new_col'] = cancer5.apply(lambda row: True if True in row.values else False, axis=1)

norm6['new_col'] = norm6.apply(lambda row: True if True in row.values else False, axis=1)
cancer6['new_col'] = cancer6.apply(lambda row: True if True in row.values else False, axis=1)

norm7['new_col'] = norm7.apply(lambda row: True if True in row.values else False, axis=1)
cancer7['new_col'] = cancer7.apply(lambda row: True if True in row.values else False, axis=1)

norm8['new_col'] = norm8.apply(lambda row: True if True in row.values else False, axis=1)
cancer8['new_col'] = cancer8.apply(lambda row: True if True in row.values else False, axis=1)

norm9['new_col'] = norm9.apply(lambda row: True if True in row.values else False, axis=1)
cancer9['new_col'] = cancer9.apply(lambda row: True if True in row.values else False, axis=1)

norm10['new_col'] = norm10.apply(lambda row: True if True in row.values else False, axis=1)
cancer10['new_col'] = cancer10.apply(lambda row: True if True in row.values else False, axis=1)

norm11['new_col'] = norm11.apply(lambda row: True if True in row.values else False, axis=1)
cancer11['new_col'] = cancer11.apply(lambda row: True if True in row.values else False, axis=1)

norm12['new_col'] = norm12.apply(lambda row: True if True in row.values else False, axis=1)
cancer12['new_col'] = cancer12.apply(lambda row: True if True in row.values else False, axis=1)

norm13['new_col'] = norm13.apply(lambda row: True if True in row.values else False, axis=1)
cancer13['new_col'] = cancer13.apply(lambda row: True if True in row.values else False, axis=1)

# %%
genes_under_study1 = genes1["rownames(eset)"][cancer1['new_col']].apply(str)
myfile1 = genes_under_study1.tolist()
with open('cancer1.txt', 'w') as f:
     print(myfile1, file=f)

genes_under_study2 = genes2["rownames(eset)"][cancer2['new_col']].apply(str)
myfile2 = genes_under_study2.tolist()
with open('cancer2.txt', 'w') as f:
     print(myfile2, file=f)

genes_under_study3 = genes3["rownames(eset)"][cancer3['new_col']].apply(str)
myfile3 = genes_under_study3.tolist()
with open('cancer3.txt', 'w') as f:
     print(myfile3, file=f)

genes_under_study4 = genes4["rownames(eset)"][cancer4['new_col']].apply(str)
myfile4 = genes_under_study4.tolist()
with open('cancer4.txt', 'w') as f:
     print(myfile4, file=f)

genes_under_study5 = genes5["rownames(eset)"][cancer5['new_col']].apply(str)
myfile5 = genes_under_study5.tolist()
with open('cancer5.txt', 'w') as f:
     print(myfile5, file=f)

genes_under_study6 = genes6["rownames(eset)"][cancer6['new_col']].apply(str)
myfile6 = genes_under_study6.tolist()
with open('cancer6.txt', 'w') as f:
     print(myfile6, file=f)

genes_under_study7 = genes7["rownames(eset)"][cancer7['new_col']].apply(str)
myfile7 = genes_under_study7.tolist()
with open('cancer7.txt', 'w') as f:
     print(myfile7, file=f)

genes_under_study8 = genes8["rownames(eset)"][cancer8['new_col']].apply(str)
myfile8 = genes_under_study8.tolist()
with open('cancer8.txt', 'w') as f:
     print(myfile8, file=f)

genes_under_study9 = genes9["rownames(eset)"][cancer9['new_col']].apply(str)
myfile9 = genes_under_study9.tolist()
with open('cancer9.txt', 'w') as f:
     print(myfile9, file=f)

genes_under_study10 = genes10["rownames(eset)"][cancer10['new_col']].apply(str)
myfile10 = genes_under_study10.tolist()
with open('cancer10.txt', 'w') as f:
     print(myfile10, file=f)

genes_under_study11 = genes11["rownames(eset)"][cancer11['new_col']].apply(str)
myfile11 = genes_under_study11.tolist()
with open('cancer11.txt', 'w') as f:
     print(myfile11, file=f)

genes_under_study12 = genes12["rownames(eset)"][cancer12['new_col']].apply(str)
myfile12 = genes_under_study12.tolist()
with open('cancer12.txt', 'w') as f:
     print(myfile12, file=f)

genes_under_study13 = genes13["rownames(eset)"][cancer13['new_col']].apply(str)
myfile13 = genes_under_study13.tolist()
with open('cancer13.txt', 'w') as f:
     print(myfile13, file=f)

# %%
genes_under_study1 = genes1["rownames(eset)"][norm1['new_col']].apply(str)
myfile1 = genes_under_study1.tolist()
with open('norm1_1.txt', 'w') as f:
     print(myfile1, file=f)

genes_under_study2 = genes2["rownames(eset)"][norm2['new_col']].apply(str)
myfile2 = genes_under_study2.tolist()
with open('norm2_1.txt', 'w') as f:
     print(myfile2, file=f)

genes_under_study3 = genes3["rownames(eset)"][norm3['new_col']].apply(str)
myfile3 = genes_under_study3.tolist()
with open('norm3_1.txt', 'w') as f:
     print(myfile3, file=f)

genes_under_study4 = genes4["rownames(eset)"][norm4['new_col']].apply(str)
myfile4 = genes_under_study4.tolist()
with open('norm4_1.txt', 'w') as f:
     print(myfile4, file=f)

genes_under_study5 = genes5["rownames(eset)"][norm5['new_col']].apply(str)
myfile5 = genes_under_study5.tolist()
with open('norm5_1.txt', 'w') as f:
     print(myfile5, file=f)

genes_under_study6 = genes6["rownames(eset)"][norm6['new_col']].apply(str)
myfile6 = genes_under_study6.tolist()
with open('norm6_1.txt', 'w') as f:
     print(myfile6, file=f)

genes_under_study7 = genes7["rownames(eset)"][norm7['new_col']].apply(str)
myfile7 = genes_under_study7.tolist()
with open('norm7_1.txt', 'w') as f:
     print(myfile7, file=f)

genes_under_study8 = genes8["rownames(eset)"][norm8['new_col']].apply(str)
myfile8 = genes_under_study8.tolist()
with open('norm8_1.txt', 'w') as f:
     print(myfile8, file=f)

genes_under_study9 = genes9["rownames(eset)"][norm9['new_col']].apply(str)
myfile9 = genes_under_study9.tolist()
with open('norm9_1.txt', 'w') as f:
     print(myfile9, file=f)

genes_under_study10 = genes10["rownames(eset)"][norm10['new_col']].apply(str)
myfile10 = genes_under_study10.tolist()
with open('norm10_1.txt', 'w') as f:
     print(myfile10, file=f)

genes_under_study11 = genes11["rownames(eset)"][norm11['new_col']].apply(str)
myfile11 = genes_under_study11.tolist()
with open('norm11_1.txt', 'w') as f:
     print(myfile11, file=f)

genes_under_study12 = genes12["rownames(eset)"][norm12['new_col']].apply(str)
myfile12 = genes_under_study12.tolist()
with open('norm12_1.txt', 'w') as f:
     print(myfile12, file=f)

genes_under_study13 = genes13["rownames(eset)"][norm13['new_col']].apply(str)
myfile13 = genes_under_study13.tolist()
with open('norm13_1.txt', 'w') as f:
     print(myfile13, file=f)
